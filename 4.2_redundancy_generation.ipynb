# %% [markdown]
# This script looks at whether generation for very redundant classes, produces high-identity sequences.

# %%
import os

# %% [markdown]
# # First: Compute redundancy in the natural classes

# %%
natural_sequences = {}
brenda = open('/agh/projects/noelia/NLP/zymCTRL/dataset_preparation/brenda_uniprot.txt', 'r')
for line in brenda:
    columns = line.split('\t')
    key = columns[5]
    if key not in natural_sequences:
        natural_sequences[key] = []
        natural_sequences[key].append(columns[6].strip())
    else:
        natural_sequences[key].append(columns[6].strip())        
brenda.close()

# %%
natural_sequences.keys()
# Out:
# dict_keys(['EC number', '2.7.1.137', '2.3.1.-; 3.1.1.32; 3.1.1.4', '3.4.21.91; 3.6.1.15; 3.6.4.13; 2.1.1.56; 2.1.1.57; 2.7.7.48', '2.7.11.1', '4.1.1.65', '5.2.1.8', '3.4.25.1', '1.10.3.9', '3.1.3.48', '3.1.3.16; 3.1.3.48; 3.1.3.67', '3.4.23.-', '3.1.3.23', '2.4.1.370', '1.7.3.3', '2.3.2.26', '3.4.21.73', '1.13.11.11', '3.2.2.27', '2.7.7.52', '2.4.2.9', '', '2.7.7.49', '3.4.23.16', '7.1.1.9', '1.14.11.2', '3.6.4.13', '7.1.1.2', '1.3.8.7', '6.1.1.2', '3.4.19.12', '2.3.2.27; 3.1.-.-', '4.2.1.1', '2.4.1.-', '3.5.4.16', '2.7.1.107', '3.2.1.1', '1.13.11.20', '2.7.4.8', '3.6.4.12', '2.4.1.25; 3.2.1.33', '7.2.2.10', '3.1.3.56', '2.7.1.153', '2.1.1.n8', '3.1.4.-', '2.7.10.1', '2.3.1.225', '2.3.1.199', '2.3.1.286', '3.1.4.11', '2.7.11.-', '2.3.2.2; 3.4.19.13', '2.5.1.26', '2.5.1.25', '4.1.99.22', '5.6.2.1', '2.7.10.2', '2.7.11.11', '6.4.1.2', '1.4.3.5', '3.1.3.5', '5.3.1.6', '2.4.2.10; 4.1.1.23', '3.1.3.4', '1.3.3.3', '3.4.24.-', '6.3.2.17', '3.2.1.23', '3.5.1.98', '2.7.7.7', '3.1.3.16', '2.3.
# ...

# %%
for key, sequences in natural_sequences.items():
    if key == 'EC number': 
        continue
    if ';' in key: 
        continue
    if key == '':
        continue
    print(key, len(sequences))
    if len(sequences) > 300:
        continue
    path = f'/agh/projects/noelia/NLP/zymCTRL/redundancy/{key}/'
    if os.path.exists(path):
        continue
    else:
        os.mkdir(path)
    for index,sequence in enumerate(sequences):
        fn = open(f'{path}/{key}_{index}.fasta','w')
        fn.write(f'>{key}_{index}\n')
        fn.write(f'{sequence}\n')
        fn.close()
# Out:
# 2.7.1.137 3683
# 2.7.11.1 419319
# 4.1.1.65 32755
# 5.2.1.8 304316
# 3.4.25.1 12972
# 1.10.3.9 26622
# 3.1.3.48 112781
# 3.4.23.- 10646
# 3.1.3.23 4287
# 2.4.1.370 7
# 1.7.3.3 6583
# 2.3.2.26 37296
# 3.4.21.73 745
# 1.13.11.11 10036
# 3.2.2.27 56064
# 2.7.7.52 133
# 2.4.2.9 45998
# 2.7.7.49 48808
# 3.4.23.16 132
# 7.1.1.9 1738201
# 1.14.11.2 7058
# 3.6.4.13 144637
# 7.1.1.2 319581
# 1.3.8.7 2812
# 6.1.1.2 57808
# 3.4.19.12 99251
# 4.2.1.1 57973
# 2.4.1.- 178403
# 3.5.4.16 49640
# 2.7.1.107 33893
# 3.2.1.1 25432
# 1.13.11.20 5321
# 2.7.4.8 42367
# 3.6.4.12 511411
# 7.2.2.10 29474
# 3.1.3.56 4221
# 2.7.1.153 3756
# 2.1.1.n8 1664
# 3.1.4.- 71424
# 2.7.10.1 65673
# 2.3.1.225 49711
# 2.3.1.199 19204
# 2.3.1.286 24274
# 3.1.4.11 29906
# 2.7.11.- 24036
# 2.5.1.26 3184
# 2.5.1.25 13574
# 4.1.99.22 33344
# 5.6.2.1 82045
# 2.7.10.2 63498
# 2.7.11.11 3400
# 6.4.1.2 9987
# 1.4.3.5 26773
# 3.1.3.5 40907
# 5.3.1.6 39857
# 3.1.3.4 6006
# 1.3.3.3 18017
# 3.4.24.- 178919
# 6.3.2.17 6482
# ...

# %%
key
# Out:
# ''
